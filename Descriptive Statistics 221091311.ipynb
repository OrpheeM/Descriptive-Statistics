# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('study_performance.csv')

# %% [markdown]
# ## Cleaning the data

# %%
# Read the head of the data 
df.head()
# Out:
#    gender race_ethnicity parental_level_of_education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test_preparation_course  math_score  reading_score  writing_score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
# check the data type 
df.dtypes
# Out:
# gender                         object
# race_ethnicity                 object
# parental_level_of_education    object
# lunch                          object
# test_preparation_course        object
# math_score                      int64
# reading_score                   int64
# writing_score                   int64
# dtype: object

# %% [markdown]
# ## Check for missing values

# %%
# show the sum of missing values per column 
df.isnull().sum()
# Out:
# gender                         0
# race_ethnicity                 0
# parental_level_of_education    0
# lunch                          0
# test_preparation_course        0
# math_score                     0
# reading_score                  0
# writing_score                  0
# dtype: int64

# %%
# data is clean and has no missing values

# %% [markdown]
# ## Descriptive Statistics

# %%
df.describe()
# Out:
#        math_score  reading_score  writing_score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %% [markdown]
# ## Range

# %%
df['math_score'].max()-df['math_score'].min()
# Out:
# 100

# %%
df['reading_score'].max()-df['reading_score'].min()
# Out:
# 83

# %%
df['writing_score'].max()-df['writing_score'].min()
# Out:
# 90

# %% [markdown]
# ## Mode

# %%
df.mode()
# Out:
#    gender race_ethnicity parental_level_of_education     lunch  \
# 0  female        group C                some college  standard
#
#   test_preparation_course  math_score  reading_score  writing_score
# 0                    none          65             72             74

# %% [markdown]
# ## Variance

# %%
df['math_score'].var()
# Out:
# 229.91899799799847

# %%
df['writing_score'].var()
# Out:
# 230.90799199199168

# %%
df['reading_score'].var()
# Out:
# 213.1656046046047

# %% [markdown]
# ## IQR

# %%
df['writing_score'].quantile(0.75)
# Out:
# 79.0

# %%
df['reading_score'].quantile(0.75)
# Out:
# 79.0

# %%
df['math_score'].quantile(0.75)
# Out:
# 77.0

# %%
df['writing_score'].quantile(0.25)
# Out:
# 57.75

# %%
df['reading_score'].quantile(0.25)
# Out:
# 59.0

# %%
df['math_score'].quantile(0.25)
# Out:
# 57.0

# %%
df['math_score'].quantile(0.95)
# Out:
# 90.04999999999995

# %%
df['writing_score'].quantile(0.95)
# Out:
# 92.0

# %%
df['reading_score'].quantile(0.95)
# Out:
# 92.0

# %% [markdown]
# ### Skewness

# %%
df['reading_score'].skew()
# Out:
# -0.25910451810923063

# %%
df['writing_score'].skew()
# Out:
# -0.28944397150761897

# %%
df['math_score'].skew()
# Out:
# -0.27893514909431694

# %% [markdown]
# ## Kurtosis

# %%
df['math_score'].kurtosis()
# Out:
# 0.27496405752108455

# %%
df['writing_score'].kurtosis()
# Out:
# -0.03336461500693577

# %%
df['reading_score'].kurtosis()
# Out:
# -0.0682654585647704

# %% [markdown]
# ## Correlation

# %%
df['reading_score'].corr(df['writing_score'])
# Out:
# 0.9545980771462477

# %% [markdown]
# ## Covariance

# %%
df['reading_score'].cov(df['writing_score'])
# Out:
# 211.78666066066063

# %% [markdown]
# ## Visualization

# %%
df.hist(figsize=(5,8))
# Out:
# array([[<Axes: title={'center': 'math_score'}>,
#         <Axes: title={'center': 'reading_score'}>],
#        [<Axes: title={'center': 'writing_score'}>, <Axes: >]],
#       dtype=object)

# %% [markdown]
# ## Outliers

# %%
plt.figure(figsize=(8,5))
sns.boxplot(df['math_score'])
plt.title("math_score" , size=10)
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.boxplot(df['writing_score'])
plt.title("writing_score" , size=10)
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.boxplot(df['reading_score'])
plt.title("reading_score" , size=10)
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.plot(df.index, df['math_score'], label='math_score')
plt.plot(df.index, df['reading_score'], label='reading_score')
plt.plot(df.index, df['writing_score'], label='writing_score')
# adding labels and tittles 
plt.ylabel('students')
plt.xlabel('scores')
plt.title ('Total Scores of both students')
plt.legend()
plt.show()

# %%
fig = plt.figure(figsize=(8, 6))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(df['math_score'], df['writing_score'], df['reading_score'])
# labels and title
ax.set_xlabel('math_score')
ax.set_ylabel('writing_score')
ax.set_zlabel('reading_score')
ax.set_title('Three-Dimensional SCatter Plot of Subject Scores')
# Out:
# Text(0.5, 0.92, 'Three-Dimensional SCatter Plot of Subject Scores')

# %%
# barplot
res = sns.barplot(df['reading_score'])
plt.show()

# %%
# barplot
res = sns.barplot(df['writing_score'])
plt.show()

# %%
# barplot
res = sns.barplot(df['math_score'])
plt.show()

# %% [markdown]
# ## Regression

# %%
x = df[['reading_score']]
y = df['writing_score']
model = LinearRegression().fit(x, y)
("Intercept:", model.intercept_)
("Coefficient:", model.coef_)
# Out:
# ('Coefficient:', array([0.99353111]))

# %%
x = df['reading_score']
y = df['writing_score']

# %%
# regplot() - regression plot

# %%
sns.regplot(x= 'reading_score' , y = 'writing_score' , data=df)
plt.show()

# %%
sns.pairplot(df)
plt.show()
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
plt.figure(figsize=(10, 6))
grouped_data = df.groupby(['gender', 'race_ethnicity', 'test_preparation_course']).size().unstack(fill_value=0)
grouped_data.plot(kind='bar', stacked=True)
plt.title('Students Gender vs Ethnicity vs Preparation')
plt.xlabel('Gender and Ethnicity')
plt.ylabel('Number of Students')
plt.xticks(rotation=45, ha='right')
plt.legend(title='Test Preparation Course', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10, 6))
grouped_data = df.groupby(['parental_level_of_education', 'lunch']).size().unstack(fill_value=0)
grouped_data.plot(kind='bar', stacked=True)
plt.title('Parental Education Level vs Lunch')
plt.xlabel('Parental level of Education')
plt.ylabel('Number of Students')
plt.xticks(rotation=45, ha='right')
plt.legend(title='Lunch', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()
